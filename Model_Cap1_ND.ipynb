# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/CAP1/DATACAP1CSV.csv')
data.head(10)
# Out:
#    BusinessEntityID PersonType                     Name  \
# 0                 1         EM            Ken J Sánchez
# 1                 2         EM          Terri Lee Duffy
# 2                 3         EM  Roberto NULL Tamburello
# 3                 4         EM         Rob NULL Walters
# 4                 5         EM          Gail A Erickson
# 5                 6         EM        Jossef H Goldberg
# 6                 7         EM           Dylan A Miller
# 7                 8         EM         Diane L Margheim
# 8                 9         EM           Gigi N Matthew
# 9                10         EM      Michael NULL Raheem
#
#                   HireDate  EmailPromotion        Thời Gian Gửi Đơn  Rate  \
# 0  2009-01-14 00:00:00.000               0                      NaN   109
# 1  2008-01-31 00:00:00.000               1  2011-11-06 13:31:21.814    60
# 2  2007-11-11 00:00:00.000               0                      NaN   114
# ...

# %%
import pandas as pd
mapping = {'Có': 0, 'Xem Xét': 1, 'Không': 2}
data['Quyết định Tăng Lương'] = data['Quyết định Tăng Lương'].replace(mapping)
print(data['Quyết định Tăng Lương'].head())
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Quyết định Tăng Lương, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data_filtered = data.drop(columns=['BusinessEntityID', 'PersonType', 'Name', 'HireDate', 'Thời Gian Gửi Đơn','Số Ngày'])
correlation_matrix = data_filtered.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Heatmap của Ma Trận Tương Quan')
plt.show()

# %%
import pandas as pd
data1= data.drop(columns=['BusinessEntityID', 'PersonType', 'Name', 'HireDate', 'Thời Gian Gửi Đơn','Rate','KPI',	'Doanh Số Đạt Được'])
data1.head(10)
# Out:
#    EmailPromotion  Vượt KPI  VacationHours  SickLeaveHours  Số Ngày  \
# 0               0    -13576             41              37      NaN
# 1               1     18415             62              46   1375.0
# 2               0      7991             44              64      NaN
# 3               0    -18805             59              53      NaN
# 4               0     -3834             68              67      NaN
# 5               0    -12346             72              20      NaN
# 6               2      3142             70              70   1032.0
# 7               0    -12624             78              48      NaN
# 8               0      8626             27              37      NaN
# 9               2    -17666             65              20   1529.0
#
#    Quyết định Tăng Lương
# 0                      2
# 1                      2
# 2                      2
# 3                      2
# 4                      2
# 5                      2
# 6                      1
# ...

# %%
data.describe()
# Out:
#        BusinessEntityID  EmailPromotion          Rate           KPI  \
# count      19972.000000    19972.000000  19972.000000  1.997200e+04
# mean        9986.500000        0.630082     67.474414  5.952738e+05
# std         5765.564124        0.781433     33.867821  2.987894e+05
# min            1.000000        0.000000      9.000000  7.940000e+04
# 25%         4993.750000        0.000000     38.000000  3.352440e+05
# 50%         9986.500000        0.000000     68.000000  5.999110e+05
# 75%        14979.250000        1.000000     97.000000  8.557550e+05
# max        19972.000000        2.000000    125.000000  1.102777e+06
#
#        Doanh Số Đạt Được      Vượt KPI  VacationHours  SickLeaveHours  \
# count       1.997200e+04  19972.000000   19972.000000    19972.000000
# mean        5.952973e+05     23.487833      49.824855       50.016824
# std         2.992540e+05  14449.454068      28.924165       17.603023
# min         5.444300e+04 -24997.000000       0.000000       20.000000
# ...

# %%
data1.isnull().sum()
# Out:
# EmailPromotion               0
# Vượt KPI                     0
# VacationHours                0
# SickLeaveHours               0
# Số Ngày                  11158
# Quyết định Tăng Lương        0
# dtype: int64

# %%
data1.nunique()
# Out:
# EmailPromotion               3
# Vượt KPI                 16414
# VacationHours              100
# SickLeaveHours              61
# Số Ngày                   1670
# Quyết định Tăng Lương        3
# dtype: int64

# %%
quyet_dinh_counts = data['Quyết định Tăng Lương'].value_counts()
print(quyet_dinh_counts)
# Out:
# Quyết định Tăng Lương
# 2    18413
# 0     1479
# 1       80
# Name: count, dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19972 entries, 0 to 19971
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EmailPromotion         19972 non-null  int64
#  1   Vượt KPI               19972 non-null  int64
#  2   VacationHours          19972 non-null  int64
#  3   SickLeaveHours         19972 non-null  int64
#  4   Số Ngày                8814 non-null   float64
#  5   Quyết định Tăng Lương  19972 non-null  int64
# dtypes: float64(1), int64(5)
# memory usage: 936.3 KB

# %% [markdown]
# # **TRỰC QUAN HÓA**

# %% [markdown]
# **THE TARGET FEATURE**

# %% [markdown]
# *Biểu đồ cột này thể hiện số lượng các trường hợp **Tăng Lương** và **Không tăng lương** và **Xem xét tăng lương** (đã được đánh giá bởi cột **"Quyết định Tăng Lương"**) trong dữ liệu. Màu đỏ được sử dụng để đại diện cho trường hợp không tăng lương, màu xanh đại diện cho nhóm tăng lương và màu cam được sử dụng để đại diện cho trường hợp Xem xét tăng lương. Điều này giúp phân biệt dễ dàng giữa ba nhóm và làm cho biểu đồ trở nên dễ đọc hơn.*

# %%
data['Quyết định Tăng Lương'].value_counts().plot(kind='bar', color=['red', 'skyblue','orange'])
# Out:
# <Axes: xlabel='Quyết định Tăng Lương'>

# %% [markdown]
# *Biểu đồ cột này thể hiện số lượng các trường hợp gửi đơn xin **Tăng Lương** 0 ,1, 2 lần trong quá trình làm việc (đã được đánh giá bởi cột **"Quyết định Tăng Lương"**) trong dữ liệu. Màu đỏ được sử dụng để đại diện cho trường hợp không tăng lương, màu xanh đại diện cho nhóm tăng lương và màu cam được sử dụng để đại diện cho trường hợp Xem xét tăng lương. Điều này giúp phân biệt dễ dàng giữa ba nhóm và làm cho biểu đồ trở nên dễ đọc hơn.*

# %%
data['EmailPromotion'].value_counts().plot(kind='bar', color=['green', 'skyblue','pink'])
# Out:
# <Axes: xlabel='EmailPromotion'>

# %% [markdown]
# *Phân phối của dữ liệu VacationHours, SickLeaveHours, Rate, KPI, Doanh Số Đạt Được, Vượt KPI trong tập dữ liệu.
# Phân phối dữ liệu: Biểu đồ hộp giúp hiểu rõ phân phối của dữ liệu tuổi thông qua việc minh họa các phần vị phần tư (25%, 50%, 75%) và các giá trị ngoại lệ (nếu có).*

# %%
import seaborn as sns
import matplotlib.pyplot as plt
bright_palette = sns.color_palette("hls", 8)
selected_columns = ['VacationHours', 'SickLeaveHours', 'Rate']
plt.figure(figsize=(6, 3))
sns.boxplot(data=data[selected_columns], palette=bright_palette, orient='h')
plt.title('Boxplot của các biến')
selected_columns1 = ['Doanh Số Đạt Được']
plt.figure(figsize=(6, 2))
sns.boxplot(data=data[selected_columns1], palette=bright_palette, orient='h')
plt.title('Boxplot của Doanh Số Đạt Được')
selected_columns1 = ['Vượt KPI']
plt.figure(figsize=(6, 2))
sns.boxplot(data=data[selected_columns1], palette=bright_palette, orient='h')
plt.title('Boxplot của KPI và Doanh Số Đạt Được')
plt.show()
# Out:
# <ipython-input-154-ba0765698e79>:6: UserWarning: The palette list has more values (8) than needed (3), which may not be intended.
#   sns.boxplot(data=data[selected_columns], palette=bright_palette, orient='h')
# <ipython-input-154-ba0765698e79>:10: UserWarning: The palette list has more values (8) than needed (1), which may not be intended.
#   sns.boxplot(data=data[selected_columns1], palette=bright_palette, orient='h')
# <ipython-input-154-ba0765698e79>:14: UserWarning: The palette list has more values (8) than needed (1), which may not be intended.
#   sns.boxplot(data=data[selected_columns1], palette=bright_palette, orient='h')

# %% [markdown]
# *   ***Hơn 50% nhân viên có VacationHours tập trung vào khoảng từ 23 đến 75 ngày***
# *   ***Hơn 50% nhân viên có SickLeaveHours tập trung khoảng từ 37 đến 62 ngày***
#
#
#
# *   ***Hơn 50% nhân viên có Rate tập trung khoảng từ 39 đến 99 đơn vị tiền tệ***
# *   ***Hơn 50% nhân viên có Doanh Số Đạt Được tập trung khoảng từ 370.000 đến 830.000 đơn vị***
#
# *   ***Hơn 50% nhân viên có Vượt KPI tập trung khoảng từ -10.300 đến 10.3000 đơn vị***

# %%
# Giá trị trung bình, trung vị và giá trị Mode Thu nhập của KH
import numpy as np
import statistics
print("Mean KPI: {}, Median KPI: {}, Mode KPI: {}".format(np.mean(data['KPI']), np.median(data['KPI'].median()), statistics.mode(data['KPI'])))
print("Mean Vượt KPI: {}, Median Vượt KPI: {}, Mode Vượt KPI: {}".format(np.mean(data['Vượt KPI']), np.median(data['Vượt KPI'].median()), statistics.mode(data['Vượt KPI'])))
# Out:
# Mean KPI: 595273.8330662928, Median KPI: 599911.0, Mode KPI: 996911
# Mean Vượt KPI: 23.487832966152613, Median Vượt KPI: 99.0, Mode Vượt KPI: 14168

# %% [markdown]
# ***Giá trị trung bình (mean), trung vị (median) và mode của cột 'KPI'và 'Vượt KPI' trong DataFrame***

# %% [markdown]
# *Biểu đồ barplot thể hiện mối liên hệ giữa biến "EmailPromotion" (Gửi đơn xin tăng lương) và biến mục tiêu "Quyết định Tăng Lương" (Quyết định). Mỗi cột biểu đồ biểu thị tỷ lệ Duyệt đơn (0), Xem xét (1) và không duyệt đơn (2) trong mỗi nhóm EmailPromotion.*

# %%
palette = {'0': 'blue', '1': 'red','2': 'orange'}
sns.barplot(data=data, x='EmailPromotion', y='Quyết định Tăng Lương', palette=palette)
plt.show()
# Out:
# <ipython-input-156-630180f9f0c7>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x='EmailPromotion', y='Quyết định Tăng Lương', palette=palette)

# %% [markdown]
# *Tỷ lệ của giá trị "Quyết định Tăng Lương" trong nhóm có EmailPromotion là Có. Nó chia số lượng các trường hợp duyệt, xem xét và không duyệt thành 3 phần và sau đó chia cho tổng số lượng quan sát trong nhóm đó. Điều này cho biết tỷ lệ duyệt, xem xét và không duyệt trong nhóm có giới tính là Nam giới.*

# %%
data[data['EmailPromotion'] == 0]['Quyết định Tăng Lương'].value_counts() / len(data[data['EmailPromotion'] == 0])
# Out:
# Quyết định Tăng Lương
# 2    1.0
# Name: count, dtype: float64

# %% [markdown]
# *Gần 20% những người không nộp đơn xin tăng lương được duyệt tăng lương, hơn 7% không nộp đơn xin tăng nhưng đưa vào xem xét và 72% còn lại quyết định không duyệt đơn tăng lương.*

# %%
data[data['EmailPromotion'] == 1]['Quyết định Tăng Lương'].value_counts() / len(data[data['EmailPromotion'] == 1])
# Out:
# Quyết định Tăng Lương
# 2    0.827121
# 0    0.165543
# 1    0.007335
# Name: count, dtype: float64

# %% [markdown]
# *Hơn 24% những người nộp đơn xin tăng 1 lần lương được duyệt, hơn 75% nộp đơn xin tăng 1 lần nhưng không được duyệt và còn lại quyết định xem xét.*

# %%
data[data['EmailPromotion'] == 2]['Quyết định Tăng Lương'].value_counts() / len(data[data['EmailPromotion'] == 2])
# Out:
# Quyết định Tăng Lương
# 2    0.817772
# 0    0.170822
# 1    0.011406
# Name: count, dtype: float64

# %% [markdown]
# *Gần 25% những người nộp đơn xin tăng 1 lần lương được duyệt, hơn 74% nộp đơn xin tăng 1 lần nhưng không được duyệt và còn lại quyết định xem xét.*

# %% [markdown]
# # **CHỌN VÀ XÂY DỰNG MÔ HÌNH**

# %% [markdown]
# **SO SÁNH CÁC THUẬT TOÁN PHÂN LỚP**
# - **Logistic Regression**
# - **K nearest neighbors**
# - **Navie Byes**
# - **Perceptron**

# %%
data1.head(10)
# Out:
#    EmailPromotion  Vượt KPI  VacationHours  SickLeaveHours  Số Ngày  \
# 0               0    -13576             41              37      NaN
# 1               1     18415             62              46   1375.0
# 2               0      7991             44              64      NaN
# 3               0    -18805             59              53      NaN
# 4               0     -3834             68              67      NaN
# 5               0    -12346             72              20      NaN
# 6               2      3142             70              70   1032.0
# 7               0    -12624             78              48      NaN
# 8               0      8626             27              37      NaN
# 9               2    -17666             65              20   1529.0
#
#    Quyết định Tăng Lương
# 0                      2
# 1                      2
# 2                      2
# 3                      2
# 4                      2
# 5                      2
# 6                      1
# ...

# %%
# Biến Phụ thuộc features và biến mục tiêu target
feature_cols = ['EmailPromotion', 'Vượt KPI', 'VacationHours','SickLeaveHours','Số Ngày']
features = data[feature_cols]
target = data['Quyết định Tăng Lương']

# %%
features
# Out:
#        EmailPromotion  Vượt KPI  VacationHours  SickLeaveHours  Số Ngày
# 0                   0    -13576             41              37      NaN
# 1                   1     18415             62              46   1375.0
# 2                   0      7991             44              64      NaN
# 3                   0    -18805             59              53      NaN
# 4                   0     -3834             68              67      NaN
# ...               ...       ...            ...             ...      ...
# 19967               0     10032             48              20      NaN
# 19968               2    -21022             30              51    321.0
# 19969               0     16916             93              39      NaN
# 19970               1     -2085             78              40    348.0
# 19971               0     -6947             99              80      NaN
#
# [19972 rows x 5 columns]

# %%
target
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 19967    2
# 19968    2
# 19969    2
# 19970    2
# 19971    2
# Name: Quyết định Tăng Lương, Length: 19972, dtype: int64

# %%
#Training Model theo tỉ lệ 70/30
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=3)
print('Train set :', X_train.shape, y_train.shape)
print('Test set :', X_test.shape, y_test.shape)
# Out:
# Train set : (13980, 5) (13980,)
# Test set : (5992, 5) (5992,)

# %% [markdown]
# **1. MODEL KNN (K-nearest neighbors)**

# %% [markdown]
# **MODEL KNN VỚI K=3**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
features_imputed = imputer.fit_transform(features)

X_train, X_test, y_train, y_test = train_test_split(features_imputed, target, test_size=0.3, random_state=3)

model_KNN = KNeighborsClassifier(n_neighbors=3)
model_KNN.fit(X_train, y_train)

y_pred = model_KNN.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
conf_mat = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("Accuracy:", accuracy)
print("Confusion Matrix:")
print(conf_mat)
print("Classification Report:")
print(class_report)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Accuracy: 0.9095460614152203
# Confusion Matrix:
# [[ 145    1  320]
#  [  10    0   14]
#  [ 194    3 5305]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.42      0.31      0.36       466
#            1       0.00      0.00      0.00        24
#            2       0.94      0.96      0.95      5502
#
#     accuracy                           0.91      5992
#    macro avg       0.45      0.43      0.44      5992
# weighted avg       0.90      0.91      0.90      5992

# %% [markdown]
# **MODEL KNN VỚI K=5**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
features_imputed = imputer.fit_transform(features)

X_train, X_test, y_train, y_test = train_test_split(features_imputed, target, test_size=0.3, random_state=3)

model_KNN = KNeighborsClassifier(n_neighbors=5)
model_KNN.fit(X_train, y_train)

y_pred = model_KNN.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
conf_mat = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("Accuracy:", accuracy)
print("Confusion Matrix:")
print(conf_mat)
print("Classification Report:")
print(class_report)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Accuracy: 0.9132176234979973
# Confusion Matrix:
# [[ 128    1  337]
#  [   8    0   16]
#  [ 154    4 5344]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.44      0.27      0.34       466
#            1       0.00      0.00      0.00        24
#            2       0.94      0.97      0.95      5502
#
#     accuracy                           0.91      5992
#    macro avg       0.46      0.42      0.43      5992
# weighted avg       0.90      0.91      0.90      5992

# %% [markdown]
# **2.MODEL NAVIE BAYES**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
features_imputed = imputer.fit_transform(features)

X_train, X_test, y_train, y_test = train_test_split(features_imputed, target, test_size=0.3, random_state=3)

model_Nav = GaussianNB()
model_Nav.fit(X_train, y_train)

y_pred = model_Nav.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_mat = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:")
print(conf_mat)
print("Classification Report:")
print(class_report)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Accuracy: 0.9432576769025367
# Confusion Matrix:
# [[ 203    0  263]
#  [   0   12   12]
#  [  65    0 5437]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.44      0.55       466
#            1       1.00      0.50      0.67        24
#            2       0.95      0.99      0.97      5502
#
#     accuracy                           0.94      5992
#    macro avg       0.90      0.64      0.73      5992
# weighted avg       0.94      0.94      0.94      5992

# %% [markdown]
# **3. MODEL PERCEPTRON**

# %%
from sklearn.linear_model import Perceptron
model_perceptron = Perceptron()
# Huấn luyện mô hình
model_perceptron.fit(X_train, y_train)
# Dự đoán nhãn của dữ liệu kiểm tra
y_pred_perceptron = model_perceptron.predict(X_test)
# Đánh giá mô hình
accuracy_perceptron = accuracy_score(y_test, y_pred_perceptron)
conf_mat_perceptron = confusion_matrix(y_test, y_pred_perceptron)
class_report_perceptron = classification_report(y_test, y_pred_perceptron)

print("Accuracy:", accuracy_perceptron)
print("Confusion Matrix:")
print(conf_mat_perceptron)
print("Classification Report:")
print(class_report_perceptron)
# Vẽ heatmap cho Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat_perceptron, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.7371495327102804
# Confusion Matrix:
# ...

# %% [markdown]
# **4. MODEL LOGISTIC REGRESSION**

# %%
from sklearn.linear_model import LogisticRegression
model_logistic = LogisticRegression()
model_logistic.fit(X_train, y_train)
y_pred_logistic = model_logistic.predict(X_test)
accuracy_logistic = accuracy_score(y_test, y_pred_logistic)
conf_mat_logistic = confusion_matrix(y_test, y_pred_logistic)
class_report_logistic = classification_report(y_test, y_pred_logistic)
print("Accuracy:", accuracy_logistic)
print("Confusion Matrix:")
print(conf_mat_logistic)
print("Classification Report:")
print(class_report_logistic)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat_logistic, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # **So sánh Kết quả các Thuật toán**
#
# 1.   **Logistic Regression**
# 2.   **K nearest neighbors với K=3**
# 2.   **K nearest neighbors với K=5**
# 4.   **Navie Byes**
# 5.  **Perceptron**

# %% [markdown]
#  *Tạo một DataFrame từ danh sách các bản ghi, mỗi bản ghi chứa các chỉ số hiệu suất cho các mô hình máy học khác nhau. DataFrame df được cấu trúc với các cột sau: 'Model', 'accuracy', 'recall', và 'f1_score'. Mỗi hàng trong DataFrame đại diện cho một mô hình khác nhau và bao gồm tên mô hình cùng với các điểm số hiệu suất tương ứng cho độ chính xác, recall và điểm F1.*
#
# *Mục đích của việc tạo ra DataFrame như vậy có thể là:*
#
# **So Sánh Các Mô Hình:** *DataFrame này cho phép so sánh dễ dàng các mô hình máy học khác nhau dựa trên các chỉ số hiệu suất của chúng. Bạn có thể nhanh chóng xem mô hình nào có độ chính xác, recall, hoặc điểm F1 cao nhất.*
#
# **Trực Quan Hóa Dữ Liệu:** *Bạn có thể muốn trực quan hóa dữ liệu này để làm cho các so sánh trở nên trực quan hơn, sử dụng các biểu đồ như biểu đồ cột hoặc biểu đồ đường.*
#
# **Báo Cáo Kết Quả:** *Định dạng này hữu ích để báo cáo kết quả một cách có cấu trúc và dễ đọc, có thể có lợi trong các bài báo học thuật, báo cáo kỹ thuật, hoặc bài thuyết trình.*

# %%
import pandas as pd
records = [('Logistic Regresstion', 0.915, 0.98, 0.96),
           ('K Nearnest Neighbor K=3', 0.909, 0.96, 0.95),
           ('K Nearnest Neighbor K=5', 0.913, 0.97, 0.95),
           ('Naive Bayes', 0.943, 0.99, 0.97),
           ('Perceptron', 0.737, 0.76, 0.84)]
df = pd.DataFrame(data = records, columns = ['Model', 'accuracy', 'recall', 'f1_score'])
df
# Out:
#                      Model  accuracy  recall  f1_score
# 0     Logistic Regresstion     0.915    0.98      0.96
# 1  K Nearnest Neighbor K=3     0.909    0.96      0.95
# 2  K Nearnest Neighbor K=5     0.913    0.97      0.95
# 3              Naive Bayes     0.943    0.99      0.97
# 4               Perceptron     0.737    0.76      0.84

# %% [markdown]
# *Mục đích của việc tạo ra `df2` như vậy có thể là để chuẩn bị dữ liệu cho việc trực quan hóa hoặc phân tích thống kê sâu hơn, ví dụ như để so sánh hiệu suất của các mô hình trên các chỉ số khác nhau bằng biểu đồ hoặc để tiến hành các kiểm định thống kê về hiệu suất của mô hình. Điều này giúp dễ dàng nhìn nhận và so sánh trực tiếp hiệu suất của từng mô hình trên các chỉ số khác nhau từ cùng một biểu đồ hoặc báo cáo.*

# %%
import pandas as pd
col = list(df['accuracy']) + list(df['recall']) + list(df['f1_score'])
stats = ['accuracy', 'accuracy', 'accuracy', 'accuracy', 'accuracy',
         'recall', 'recall', 'recall', 'recall', 'recall',
         'f1_score', 'f1_score', 'f1_score', 'f1_score', 'f1_score']
stats = stats[:len(col)]
df2 = pd.DataFrame()
df2['score'] = col
df2['algo'] = list(df['Model']) * 3
df2['stats'] = stats

# %% [markdown]
# *Việc sử dụng biểu đồ cột giúp người xem dễ dàng so sánh hiệu suất của các mô hình khác nhau trên từng chỉ số đánh giá cụ thể. Mỗi mô hình có ba cột tương ứng với ba chỉ số hiệu suất, cho phép người xem nhanh chóng nhận ra mô hình nào hoạt động tốt nhất hoặc kém nhất trên từng tiêu chí cụ thể. Đây là một cách hiệu quả để trình bày dữ liệu phức tạp một cách trực quan, làm nổi bật sự khác biệt giữa các mô hình và giữa các chỉ số đánh giá.*

# %%
import matplotlib.pyplot as plt
import seaborn as sns
custom_palette = ["blue", "green", "pink", "purple"]
fig = plt.figure(figsize=(12, 8))
sns.barplot(data=df2, x='algo', y='score', hue='stats', palette=custom_palette)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-188-fc465ffc4710>:5: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
#   sns.barplot(data=df2, x='algo', y='score', hue='stats', palette=custom_palette)

# %% [markdown]
# - *Với mục tiêu ưu tiên tìm ra thuật toán tốt nhất cho mô hình , nhóm đã sử dụng 4 thuật toán phân lớp để xây dựng mô hình, mỗi mô hình cho ra mỗi kết quả khác nhau. Để chọn ra mô hình phù hợp nhất, nhóm sẽ dùng 3 chỉ số accuracy, recall và f1-score để đánh giá*
# - *Trên đây là biểu đồ thể hiện 3 chỉ số ở mỗi mô hình*

# %% [markdown]
# -	***Ta nhận thấy:***
# - **Navie Bayes:**
#   + **Độ chính xác (Accuracy):** Cao nhất, khoảng 0.943, cho thấy mô hình này đúng đắn trong phần lớn các dự đoán.
#   + **Recall**: Cao nhất, khoảng 0.99, cho thấy khả năng phát hiện lớp quan tâm tốt.
#   + **F1-score:** Cao nhất, cho thấy sự cân bằng tốt giữa precision và recall, đặc biệt quan trọng khi các lớp có sự mất cân đối.
# - **K Nearest Neighbor với K=3:**
#   Điểm số tốt nhưng  độ chính xác có vẽ thấp hơn so vớ phân K thành 5 lớp, mô hình tương đối nhưng chưa phải là model tốt nhất.
# - **K Nearest Neighbor với K=5:**
#   Điểm số tốt nhưng không vượt trội. Có thể phù hợp với các bài toán cần mô hình đơn giản và dễ giải thích tuy nhiên chưa cao hơn thuật toán navie bayes.
# - **Logistic Regression:**
#   Có hiệu suất thấp trong cả độ chính xác chỉ cao hơn perceptron, có thể không phải là lựa chọn tốt nhất cho tập dữ liệu này.
# - **Perceptron:**
#   Cả 3 chỉ số đều thấp nhất trong các model có thể thuật toán chưa phù hợp với bài toán này.

# %% [markdown]
# ***Đánh giá tổng thể:***
#
# * **Navie Bayes** nổi bật là mô hình có hiệu suất tổng thể tốt nhất, có thể là lựa chọn tốt nhất cho bài toán phân loại nếu bạn cần một mô hình mạnh mẽ và cân bằng.*
# * **KNN với K=5** có thể được xem xét nếu bạn cần một mô hình đơn giản và dễ giải thích. Mặc dù không mạnh như Navie Bayes, nhưng nó cung cấp một cân bằng tốt giữa hiệu suất và tính minh bạch.*
# * **Các mô hình khác** có thể hữu ích cho những tình huống cụ thể, tuy nhiên, dựa trên ba chỉ số được đánh giá, chúng không phải là lựa chọn tốt nhất cho tập dữ liệu này.*
# * **Perceptron** có vẻ không phù hợp với tập dữ liệu này dựa trên hiệu suất tổng thể.*

# %% [markdown]
# ***-	Rút ra kết luận:***
#
# ***Chọn Mô Hình Tốt Nhất:***
#
# *Dựa trên biểu đồ, **Navie Bayes** có vẻ là lựa chọn tốt nhất bởi nó đạt điểm cao nhất ở cả ba chỉ số đánh giá, cho thấy sự cân bằng giữa độ chính xác và khả năng tái tạo kết quả.*

# %% [markdown]
# **TEST DỮ LIỆU TRONG TẬP TEST NAVIE BAYES**

# %%
y_pred_first_10 = model_Nav.predict(X_test[10:25])
print("Predicted\tActual")
for pred, actual in zip(y_pred_first_10, y_test[10:25]):
    print(f"{pred}\t\t{actual}")
# Out:
# Predicted	Actual
# 2		2
# 2		2
# 2		2
# 2		2
# 2		2
# 2		2
# 2		2
# 2		2
# 2		2
# 2		0
# 2		2
# 2		2
# 2		0
# 2		2
# 2		2

# %% [markdown]
# **TEST DỮ LIỆU MỚI VỚI NAVIE BAYES**

# %%
# Dữ liệu mới cần dự đoán
new_data = [[0, 4500, 80, 70,505]]
predicted_label = model_Nav.predict(new_data)
feature_names = ['EmailPromotion', 'Vượt KPI', 'VacationHours','SickLeaveHours','Số Ngày']
predicted_label_text = "Quyết Định Duyệt Đơn Tăng Lương" if predicted_label == 0 else "Quyết Định Xem Xét Tăng Lương" if predicted_label == 1 else "Quyết Định Không Duyệt Đơn Tăng Lương"
print("Thông tin Nhân viên:")
print("- Có Gửi Đơn Xin Tăng Lương Không:","Có Gửi 1 Lần" if new_data[0][0] ==1 else "Có Gửi 2 Lần" if new_data[0][0] ==2 else "Không Gửi")
print("- Vượt KPI:", new_data[0][1])
print("- VacationHours:", new_data[0][2])
print("- SickLeaveHours:", new_data[0][3])
print("- Số Ngày':", new_data[0][4])
print("Mô hình Dự đoán:", predicted_label_text)
# Out:
# Thông tin Nhân viên:
# - Có Gửi Đơn Xin Tăng Lương Không: Không Gửi
# - Vượt KPI: 4500
# - VacationHours: 80
# - SickLeaveHours: 70
# - Số Ngày': 505
# Mô hình Dự đoán: Quyết Định Không Duyệt Đơn Tăng Lương

# %%
# Dữ liệu mới cần dự đoán
new_data =[[2, 15666, 15, 26, 654]]
predicted_label = model_Nav.predict(new_data)
feature_names = ['EmailPromotion', 'Vượt KPI', 'VacationHours','SickLeaveHours','Số Ngày']
predicted_label_text = "Quyết Định Duyệt Đơn Tăng Lương" if predicted_label == 0 else "Quyết Định Xem Xét Tăng Lương" if predicted_label == 1 else "Quyết Định Không Duyệt Đơn Tăng Lương"
print("Thông tin Nhân viên:")
print("- Có Gửi Đơn Xin Tăng Lương Không:","Có Gửi 1 Lần" if new_data[0][0] ==1 else "Có Gửi 2 Lần" if new_data[0][0] ==2 else "Không Gửi")
print("- Vượt KPI:", new_data[0][1])
print("- VacationHours:", new_data[0][2])
print("- SickLeaveHours:", new_data[0][3])
print("- Số Ngày':", new_data[0][4])
print("Mô hình Dự đoán:", predicted_label_text)
# Out:
# Thông tin Nhân viên:
# - Có Gửi Đơn Xin Tăng Lương Không: Có Gửi 2 Lần
# - Vượt KPI: 15666
# - VacationHours: 15
# - SickLeaveHours: 26
# - Số Ngày': 654
# Mô hình Dự đoán: Quyết Định Duyệt Đơn Tăng Lương

# %%
# Dữ liệu mới cần dự đoán
new_data =[[1, 12500, 42, 46, 310]]
predicted_label = model_Nav.predict(new_data)
feature_names = ['EmailPromotion', 'Vượt KPI', 'VacationHours','SickLeaveHours','Số Ngày']
predicted_label_text = "Quyết Định Duyệt Đơn Tăng Lương" if predicted_label == 0 else "Quyết Định Xem Xét Tăng Lương" if predicted_label == 1 else "Quyết Định Không Duyệt Đơn Tăng Lương"
print("Thông tin Nhân viên:")
print("- Có Gửi Đơn Xin Tăng Lương Không:","Có Gửi 1 Lần" if new_data[0][0] ==1 else "Có Gửi 2 Lần" if new_data[0][0] ==2 else "Không Gửi")
print("- Vượt KPI:", new_data[0][1])
print("- VacationHours:", new_data[0][2])
print("- SickLeaveHours:", new_data[0][3])
print("- Số Ngày':", new_data[0][4])
print("Mô hình Dự đoán:", predicted_label_text)
# Out:
# Thông tin Nhân viên:
# - Có Gửi Đơn Xin Tăng Lương Không: Có Gửi 1 Lần
# - Vượt KPI: 12500
# - VacationHours: 42
# - SickLeaveHours: 46
# - Số Ngày': 310
# Mô hình Dự đoán: Quyết Định Không Duyệt Đơn Tăng Lương
